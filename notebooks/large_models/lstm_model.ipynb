# %%
import os
import sys
sys.path.append(os.path.join(os.getcwd().replace("notebooks/large_models", "")))

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from config import Config
from data.dataset import NetworkDataset, load_datasets
from model_config import LSTM_Models

# %%
conf = Config()
load_models = LSTM_Models()
model = load_models.lstm_4

# %%
X_train, y_train, X_val, y_val, X_test, y_test = load_datasets(conf.datasets, "lstm")

# create train, val and test dataloaders
train_dataset = NetworkDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, conf.batch_size, shuffle=True)

val_dataset = NetworkDataset(X_val, y_val)
val_loader = DataLoader(val_dataset, conf.batch_size, shuffle=True)

test_dataset = NetworkDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, conf.batch_size)

# %%
data, labels = next(iter(train_loader))
print(data.shape, labels.shape)
# Out:
# torch.Size([512, 513, 1]) torch.Size([512])

# %%
acc, train_loss, val_loss = model.train(train_loader, val_loader, conf.epochs)
# Out:
# Epoch: 1/10, Accuracy: 88.09%, Train loss: 0.8111, Val loss: 0.2309
# Epoch: 2/10, Accuracy: 93.58%, Train loss: 0.2036, Val loss: 0.1098
# Epoch: 3/10, Accuracy: 94.70%, Train loss: 0.1221, Val loss: 0.0793
# Epoch: 4/10, Accuracy: 95.17%, Train loss: 0.0955, Val loss: 0.0674
# Epoch: 5/10, Accuracy: 95.76%, Train loss: 0.0814, Val loss: 0.0598
# Epoch: 6/10, Accuracy: 96.39%, Train loss: 0.0734, Val loss: 0.0551
# Epoch: 7/10, Accuracy: 96.17%, Train loss: 0.0674, Val loss: 0.0533
# Epoch: 8/10, Accuracy: 96.56%, Train loss: 0.0639, Val loss: 0.0497
# Epoch: 9/10, Accuracy: 96.60%, Train loss: 0.0608, Val loss: 0.0478
# Epoch: 10/10, Accuracy: 96.68%, Train loss: 0.0582, Val loss: 0.0475

# %%
loss, accuracy = model.evaluate(test_loader)
print(f" Accuracy: {100*accuracy:.2f}%")
# Out:
#  Accuracy: 96.64%

# %%
model.save()
# Out:
# Checkpoint saved at /global/D1/homes/jorgetf/Network-Packet-ML-Model/checkpoint/large_model/lstm_4.pth
