# %%
import os
import sys
sys.path.append(os.path.join(os.getcwd().replace("notebooks/split_models", "")))

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from config import Config
from data.dataset import NetworkDataset, load_datasets
from model_config import LSTM_Models

# %%
conf = Config()
load_models = LSTM_Models()
model = load_models.split_lstm_0

# %%
X_train, y_train, X_val, y_val, X_test, y_test = load_datasets(conf.datasets, "lstm")

# create train, val and test dataloaders
train_dataset = NetworkDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, conf.batch_size, shuffle=True)

val_dataset = NetworkDataset(X_val, y_val)
val_loader = DataLoader(val_dataset, conf.batch_size, shuffle=True)

test_dataset = NetworkDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, conf.batch_size)

# %%
data, labels = next(iter(train_loader))
print(data.shape, labels.shape)
# Out:
# torch.Size([512, 513, 1]) torch.Size([512])

# %%
acc, train_loss, val_loss = model.train(train_loader, val_loader, conf.epochs)
# Out:
# Epoch: 1/10, Accuracy: 88.67%, Train loss: 0.9440, Val loss: 0.2527
# Epoch: 2/10, Accuracy: 92.86%, Train loss: 0.2196, Val loss: 0.1212
# Epoch: 3/10, Accuracy: 94.13%, Train loss: 0.1315, Val loss: 0.0920
# Epoch: 4/10, Accuracy: 94.96%, Train loss: 0.1025, Val loss: 0.0732
# Epoch: 5/10, Accuracy: 95.34%, Train loss: 0.0866, Val loss: 0.0656
# Epoch: 6/10, Accuracy: 95.72%, Train loss: 0.0779, Val loss: 0.0602
# Epoch: 7/10, Accuracy: 96.00%, Train loss: 0.0722, Val loss: 0.0569
# Epoch: 8/10, Accuracy: 96.34%, Train loss: 0.0680, Val loss: 0.0527
# Epoch: 9/10, Accuracy: 96.41%, Train loss: 0.0645, Val loss: 0.0507
# Epoch: 10/10, Accuracy: 96.37%, Train loss: 0.0611, Val loss: 0.0490

# %%
loss, accuracy = model.evaluate(test_loader)
print(f" Accuracy: {100*accuracy:.2f}%")
# Out:
#  Accuracy: 96.34%

# %%
model.save()
# Out:
# Checkpoint saved at /global/D1/homes/jorgetf/Network-Packet-ML-Model/checkpoint/split_model/split_lstm_0.pth
