# %%
import os
import sys
sys.path.append(os.path.join(os.getcwd().replace("split_models", "")))

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from config import Config
from data.dataset import NetworkDataset, load_datasets
from model_config import GRU_Models

# %%
conf = Config()
load_models = GRU_Models()
model = load_models.split_gru_3

# %%
X_train, y_train, X_val, y_val, X_test, y_test = load_datasets(conf.datasets, "lstm")

# create train, val and test dataloaders
train_dataset = NetworkDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, conf.batch_size, shuffle=True)

val_dataset = NetworkDataset(X_val, y_val)
val_loader = DataLoader(val_dataset, conf.batch_size, shuffle=True)

test_dataset = NetworkDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, conf.batch_size)

# %%
data, labels = next(iter(train_loader))
print(data.shape, labels.shape)
# Out:
# torch.Size([512, 513, 1]) torch.Size([512])

# %%
acc, train_loss, val_loss = model.train(train_loader, val_loader, conf.epochs)
# Out:
# Epoch: 1/10, Accuracy: 85.40%, Train loss: 0.8090, Val loss: 0.2689
# Epoch: 2/10, Accuracy: 92.57%, Train loss: 0.2211, Val loss: 0.1264
# Epoch: 3/10, Accuracy: 94.11%, Train loss: 0.1358, Val loss: 0.0960
# Epoch: 4/10, Accuracy: 94.84%, Train loss: 0.1102, Val loss: 0.0816
# Epoch: 5/10, Accuracy: 95.13%, Train loss: 0.0970, Val loss: 0.0738
# Epoch: 6/10, Accuracy: 95.34%, Train loss: 0.0883, Val loss: 0.0684
# Epoch: 7/10, Accuracy: 95.60%, Train loss: 0.0820, Val loss: 0.0630
# Epoch: 8/10, Accuracy: 95.80%, Train loss: 0.0775, Val loss: 0.0597
# Epoch: 9/10, Accuracy: 95.91%, Train loss: 0.0735, Val loss: 0.0575
# Epoch: 10/10, Accuracy: 96.12%, Train loss: 0.0703, Val loss: 0.0544

# %%
loss, accuracy = model.evaluate(test_loader)
print(f" Accuracy: {100*accuracy:.2f}%")
# Out:
#  Accuracy: 96.00%

# %%
model.save()
# Out:
# Checkpoint saved at /global/D1/homes/jorgetf/Network-Packet-ML-Model/split_models/checkpoint/split_gru_3.pth
