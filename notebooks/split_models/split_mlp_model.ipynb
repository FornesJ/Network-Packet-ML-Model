# %%
import os
import sys
sys.path.append(os.path.join(os.getcwd().replace("notebooks/split_models", "")))

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from config import Config
from data.dataset import NetworkDataset, load_datasets
from model_config import MLP_Models

# %%
conf = Config()
load_models = MLP_Models()
model = load_models.split_mlp_1

# %%
X_train, y_train, X_val, y_val, X_test, y_test = load_datasets(conf.datasets, "mlp")

# create train, val and test dataloaders
train_dataset = NetworkDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, conf.batch_size, shuffle=True)

val_dataset = NetworkDataset(X_val, y_val)
val_loader = DataLoader(val_dataset, conf.batch_size, shuffle=True)

test_dataset = NetworkDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, conf.batch_size)

# %%
data, labels = next(iter(train_loader))
print(data.shape, labels.shape)
# Out:
# torch.Size([512, 513]) torch.Size([512])

# %%
acc, train_loss, val_loss = model.train(train_loader, val_loader, conf.epochs)
# Out:
# Epoch: 1/20, Accuracy: 65.20%, Train loss: 1.7187, Val loss: 1.2832
# Epoch: 2/20, Accuracy: 68.44%, Train loss: 0.9118, Val loss: 0.7778
# Epoch: 3/20, Accuracy: 77.33%, Train loss: 0.5967, Val loss: 0.5221
# Epoch: 4/20, Accuracy: 81.44%, Train loss: 0.4698, Val loss: 0.4184
# Epoch: 5/20, Accuracy: 83.36%, Train loss: 0.3997, Val loss: 0.3524
# Epoch: 6/20, Accuracy: 84.80%, Train loss: 0.3501, Val loss: 0.3362
# Epoch: 7/20, Accuracy: 75.23%, Train loss: 0.3096, Val loss: 0.4243
# Epoch: 8/20, Accuracy: 86.23%, Train loss: 0.2807, Val loss: 0.2769
# Epoch: 9/20, Accuracy: 87.19%, Train loss: 0.2561, Val loss: 0.2343
# Epoch: 10/20, Accuracy: 87.99%, Train loss: 0.2374, Val loss: 0.1980
# Epoch: 11/20, Accuracy: 89.15%, Train loss: 0.2204, Val loss: 0.1993
# Epoch: 12/20, Accuracy: 88.90%, Train loss: 0.2069, Val loss: 0.1823
# Epoch: 13/20, Accuracy: 90.08%, Train loss: 0.1957, Val loss: 0.1585
# Epoch: 14/20, Accuracy: 90.34%, Train loss: 0.1868, Val loss: 0.1693
# Epoch: 15/20, Accuracy: 91.18%, Train loss: 0.1786, Val loss: 0.1450
# Epoch: 16/20, Accuracy: 88.69%, Train loss: 0.1708, Val loss: 0.2830
# Epoch: 17/20, Accuracy: 91.22%, Train loss: 0.1648, Val loss: 0.1351
# Epoch: 18/20, Accuracy: 91.53%, Train loss: 0.1591, Val loss: 0.1293
# Epoch: 19/20, Accuracy: 91.67%, Train loss: 0.1551, Val loss: 0.1201
# Epoch: 20/20, Accuracy: 91.86%, Train loss: 0.1518, Val loss: 0.1240

# %%
loss, accuracy = model.evaluate(test_loader)
print(f" Accuracy: {100*accuracy:.2f}%")
# Out:
#  Accuracy: 91.78%

# %%
model.save()
# Out:
# Checkpoint saved at /global/D1/homes/jorgetf/Network-Packet-ML-Model/checkpoint/split_model/split_mlp_1.pth
