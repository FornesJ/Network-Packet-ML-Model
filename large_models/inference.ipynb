# %%
import os
import sys
sys.path.append(os.path.join(os.getcwd().replace("large_models", "")))

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from utils.config import Config
from utils.parse_dataset import NetworkDataset, load_datasets
from utils.load_models import MLP_Models, LSTM_Models, GRU_Models
from utils.benchmark import Benchmark

# %%
conf = Config()
models = [MLP_Models().mlp_4, LSTM_Models().lstm_4, GRU_Models().gru_4]
model_names = ["mlp_4", "lstm_4", "gru_4"]

# %%
X_train, y_train, X_val, y_val, X_test, y_test = load_datasets(conf.datasets, "mlp")

mlp_dataset = NetworkDataset(X_test, y_test)
mlp_loader = DataLoader(mlp_dataset, conf.batch_size)

X_train, y_train, X_val, y_val, X_test, y_test = load_datasets(conf.datasets, "lstm")

rnn_dataset = NetworkDataset(X_test, y_test)
rnn_loader = DataLoader(rnn_dataset, conf.batch_size)

# %%
for i in range(len(models)):
    # set parameters
    model = models[i]
    loader = rnn_loader if i > 0 else mlp_loader
    name = model_names[i]
    result_path = os.path.join(conf.large_models_path, "benchmarks", name + ".txt")

    # run benchmark
    benchmark = Benchmark(model, loader, conf.batch_size, name, result_path)
    benchmark()

    # print and save result
    benchmark.print_result()
    benchmark.save()
# Out:
# Checkpoint loaded from /home/jorgetf/testmodel/Network-Packet-ML-Model/large_models/checkpoint/mlp_4.pth!
# [W1203 15:59:51.290547563 CPUAllocator.cpp:245] Memory block of unknown size was allocated before the profiling started, profiler results will not include the deallocation event
# ERROR:2025-12-03 15:59:51 457879:457879 DeviceProperties.cpp:47] gpuGetDeviceCount failed with code 35
# Benchmark - mlp_4 model:
#
# Memory usage (MB):
# Avg memory usage: 2.953MB
# Peak memory usage: 10.469MB
#
# Model inference latency on one batch (batch size = 512):
# Avg latency: 1.488ms
# Min latency: 1.055ms
# Max latency: 2.645ms
#
# Model inference throughput (batch size = 512):
# Throughput: 90745.85 samples/sec
#
# Model inference CPU usage (number of logical cores) during runtime:
# CPU runtime: 0.28 seconds
# Average CPU usage: 48.05/96 cores
#
# Model (mlp_4) inference accuracy (%):
# Accuracy: 84.57%
#
#
#
# Checkpoint loaded from /home/jorgetf/testmodel/Network-Packet-ML-Model/large_models/checkpoint/lstm_4.pth!
# Benchmark - lstm_4 model:
#
# Memory usage (MB):
# Avg memory usage: 410.117MB
# Peak memory usage: 5186.169MB
#
# Model inference latency on one batch (batch size = 512):
# Avg latency: 923.042ms
# Min latency: 877.026ms
# Max latency: 1025.232ms
#
# Model inference throughput (batch size = 512):
# Throughput: 546.36 samples/sec
#
# Model inference CPU usage (number of logical cores) during runtime:
# CPU runtime: 46.39 seconds
# Average CPU usage: 37.44/96 cores
#
# Model (lstm_4) inference accuracy (%):
# Accuracy: 96.68%
#
#
#
# Checkpoint loaded from /home/jorgetf/testmodel/Network-Packet-ML-Model/large_models/checkpoint/gru_4.pth!
# Benchmark - gru_4 model:
#
# Memory usage (MB):
# Avg memory usage: 1824.441MB
# Peak memory usage: 30784.219MB
#
# Model inference latency on one batch (batch size = 512):
# Avg latency: 1920.661ms
# Min latency: 1685.250ms
# Max latency: 2210.733ms
#
# Model inference throughput (batch size = 512):
# Throughput: 255.73 samples/sec
#
# Model inference CPU usage (number of logical cores) during runtime:
# CPU runtime: 97.75 seconds
# Average CPU usage: 45.43/96 cores
#
# Model (gru_4) inference accuracy (%):
# Accuracy: 97.27%
